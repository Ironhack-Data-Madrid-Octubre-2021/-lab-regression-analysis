# %% [markdown]
# # Lab: Regression Analysis

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
import statsmodels.formula.api as smf

#from matplotlib import cm
#%matplotlib inline
#%config Inlinebackend.figure_format = 'retina'


#import numpy as np

sns.set_context("poster")
sns.set(rc={"figure.figsize": (14,6)})
sns.set_style("whitegrid")

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
student_data = pd.DataFrame({'Age': [17,51,27,21,36,48,19,26,54,30], 'Tardies': [10,1,5,9,4,2,9,6,0,3]})
#student_data

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
sns.scatterplot(x=student_data["Age"], y=student_data["Tardies"]);

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
There is a clear trend: the older a person is, less Tardies he shows.

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
student_data.corr()
# Out:
#               Age   Tardies
# Age      1.000000 -0.939163
# Tardies -0.939163  1.000000

# %%
student_data.cov()
# Out:
#                 Age    Tardies
# Age      187.655556 -45.566667
# Tardies  -45.566667  12.544444

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
lr = LinearRegression()
lr.fit(X = student_data[["Age"]],    
       y = student_data.Tardies )

# We are using a linear Regresion: #Y (Tardies) = X (Age) * beta_0 + offset
beta_1 = lr.coef_[0]
beta_0 = lr.intercept_
print(beta_0, beta_1)
# Out:
# LinearRegression()

# %%
beta_0 = lr.coef_[0]
offset = lr.intercept_
print(lr, " with beta_0 =",beta_0," and offset of ", offset)
# Out:
# LinearRegression()  with beta_0 = -0.2428207709159808  and offset of  12.888803363135768

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
X = student_data.Age
y = student_data.Tardies
linea = offset + beta_0 * X
plt.scatter(X , y)
plt.plot(X,linea, lw=2)
plt.vlines(X,linea,y, lw=0.5)
plt.xlabel("Age")
plt.ylabel("Tardies");

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %% [markdown]
# Yes, seeing this pltos, we can understand that Tardies are affedted by the Age with a negative correlation.
# Nevertheless, we have only a few datas to be able to infer any conclusion. For a higher certainty, we should check a bigger population

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
vehicles = pd.read_csv("vehicles.csv")
vehicles.rename(columns= {x:x.replace(" ","_").replace("/","_") for x in vehicles.columns}, inplace=True)
vehicles.columns

# %%
vehicles.sample(3)
# Out:
#              Make        Model  Year  Engine_Displacement  Cylinders  \
# 32346      Toyota  4Runner 4WD  1985                  2.4        4.0
# 31106      Subaru  Impreza AWD  1996                  1.8        4.0
# 34150  Volkswagen       Beetle  2015                  2.0        4.0
#
#           Transmission                  Drivetrain             Vehicle_Class  \
# 32346  Automatic 4-spd  4-Wheel or All-Wheel Drive  Special Purpose Vehicles
# 31106     Manual 5-spd  4-Wheel or All-Wheel Drive           Subcompact Cars
# 34150     Manual 6-spd           Front-Wheel Drive              Compact Cars
#
#       Fuel_Type  Fuel_Barrels_Year  City_MPG  Highway_MPG  Combined_MPG  \
# 32346   Regular          17.347895        18           20            19
# 31106   Regular          14.330870        21           26            23
# 34150    Diesel          11.240735        31           41            34
#
#        CO2_Emission_Grams_Mile  Fuel_Cost_Year
# ...

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
vehicles.corr()
# Out:
#                              Year  Engine_Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine_Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel_Barrels_Year       -0.221084             0.789752   0.739517
# City_MPG                 0.161818            -0.740317  -0.703866
# Highway_MPG              0.267259            -0.715039  -0.650287
# Combined_MPG             0.204751            -0.746782  -0.698648
# CO2_Emission_Grams_Mile -0.222300             0.803520   0.752393
# Fuel_Cost_Year          -0.091913             0.769678   0.778153
#
#                          Fuel_Barrels_Year  City_MPG  Highway_MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine_Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# ...

# %% [markdown]
# The varible Fuel_Barrels_Year shows a correlation of 0.98 with CO2_Emissions.
# Fuel_Cost_Year and Combined_MPG show a correlation of 0.93 and -0.92 respectively, what is also quite high correlation.
# Cylinders (0,75) is showing also a correlation but not as high as the previous ones.
# Year (0,22) provides the least correlation for determining CO2 emissions.

# %%
sns.pairplot(vehicles[["Year", "Cylinders", "Fuel_Barrels_Year", "Combined_MPG", "Fuel_Cost_Year","CO2_Emission_Grams_Mile"]]);

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
results = smf.ols("CO2_Emission_Grams_Mile ~ Fuel_Barrels_Year + Fuel_Cost_Year + Combined_MPG + Cylinders + Year", data = vehicles).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     CO2_Emission_Grams_Mile   R-squared:                       0.981
# Model:                                 OLS   Adj. R-squared:                  0.981
# Method:                      Least Squares   F-statistic:                 3.687e+05
# Date:                     Tue, 23 Nov 2021   Prob (F-statistic):               0.00
# Time:                             18:03:29   Log-Likelihood:            -1.5173e+05
# No. Observations:                    35952   AIC:                         3.035e+05
# Df Residuals:                        35946   BIC:                         3.035e+05
# Df Model:                                5
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
The most

# %% [markdown]
# ## Bonus Challenge: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
party = pd.DataFrame({'Invited': [1,3,4,6,8,9,11,14], 'Attending': [1,2,4,4,5,7,8,13]})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
sns.regplot(x=party["Invited"], y=party["Attending"]);

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
results = smf.ols("Attending ~ Invited", data = party).fit()
results.summary()
# Out:
# /home/danihelguera/anaconda3_linux/envs/ironhack/lib/python3.8/site-packages/scipy/stats/stats.py:1541: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Attending   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     81.81
# Date:                Tue, 23 Nov 2021   Prob (F-statistic):           0.000102
# Time:                        18:09:18   Log-Likelihood:                -10.800
# No. Observations:                   8   AIC:                             25.60
# Df Residuals:                       6   BIC:                             25.76
# Df Model:                           1
# ...

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
party_clean = party[party["Invited"]<14]
party_clean
# Out:
#    Invited  Attending
# 0        1          1
# 1        3          2
# 2        4          4
# 3        6          4
# 4        8          5
# 5        9          7
# 6       11          8

# %%
sns.regplot(x=party_clean["Invited"], y=party_clean["Attending"]);

# %%
results = smf.ols("Attending ~ Invited", data = party_clean).fit()
results.summary()
# Out:
# /home/danihelguera/anaconda3_linux/envs/ironhack/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Attending   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     83.31
# Date:                Tue, 23 Nov 2021   Prob (F-statistic):           0.000264
# Time:                        18:11:02   Log-Likelihood:                -5.7771
# No. Observations:                   7   AIC:                             15.55
# Df Residuals:                       5   BIC:                             15.45
# Df Model:                           1
# ...

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
Without outliers, the Rsquared increases.
